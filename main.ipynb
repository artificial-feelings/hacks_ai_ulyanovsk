# %%
import numpy as np
import pandas as pd
import seaborn as sns
from math import sqrt
import glob

import cv2
import random
from pathlib import Path
import os
from tqdm.notebook import tqdm as tqdm
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import shutil
import json

# %% [markdown]
# # Подготовка Train

# %%
annot_df = pd.read_csv('train_no_heic.csv', sep=';')
annot_df.head()
# Out:
#      image_name  distance
# 0  img_1596.jpg      4.88
# 1  img_1600.jpg      1.54
# 2  img_1601.jpg      3.68
# 3  img_1603.jpg      2.22
# 4  img_1605.jpg      3.73

# %%
def detections_to_features_df(path_to_labels):
    records = []
    for file_name in os.listdir(path_to_labels):
        with open(path_to_labels+file_name, 'r') as f:
            lines = f.read().splitlines()
            lines = [line[2:] for line in lines]
            x_plate, y_plate, w_plate, h_plate, x_car, y_car, w_car, h_car = list(map(float,(lines[0]+' '+lines[1]).split()))        
            img_name = file_name.split('.')[0]+'.jpg'
            records.append([img_name, x_plate, y_plate, w_plate, h_plate, x_car, y_car, w_car, h_car])
    
    df = pd.DataFrame(records, columns=['image_name', 'x_plate', 'y_plate', 'w_plate',
                                          'h_plate', 'x_car', 'y_car', 'w_car', 'h_car'])
    
    df['plate_area'] = df['w_plate']*df['h_plate']
    df['car_area'] = df['w_car']*df['h_car']
    df['plate_hypotenuse'] = (df['w_plate']**2 + df['h_plate']**2).apply(sqrt)
    df['car_hypotenuse'] = (df['w_car']**2 + df['h_car']**2).apply(sqrt)
    df['car_plate_ratio'] = df['plate_area'] / df['car_area']
    df['plate_proportions'] = df['h_plate']/df['w_plate']
    df['car_proportions'] = df['h_car']/df['w_car']
    df['car_to_bottom'] = 1 - (df['y_car']+df['h_car']/2)
    
    return df

# %%
train = detections_to_features_df('train_yolo/labels/')
train = train.merge(annot_df, how='left', on='image_name')
train.shape
# Out:
# (526, 18)

# %%
train.head()
# Out:
#       image_name   x_plate   y_plate   w_plate   h_plate     x_car     y_car  \
# 0   img_1977.jpg  0.466602  0.626187  0.090690  0.026871  0.464192  0.528925
# 1   img_1963.jpg  0.460479  0.509495  0.058591  0.014483  0.463112  0.508617
# 2   img_2503.jpg  0.475444  0.546320  0.041795  0.013519  0.473837  0.501145
# 3   img_2271.jpg  0.476003  0.590207  0.049012  0.013489  0.474696  0.540411
# 4  img_2744h.jpg  0.479274  0.508476  0.078934  0.022208  0.478095  0.485804
#
#       w_car     h_car  plate_area  car_area  plate_hypotenuse  car_hypotenuse  \
# 0  0.272509  0.280979    0.002437  0.076569          0.094587        0.391421
# 1  0.171165  0.179504    0.000849  0.030725          0.060355        0.248031
# 2  0.118212  0.138162    0.000565  0.016332          0.043927        0.181832
# 3  0.135816  0.157191    0.000661  0.021349          0.050834        0.207738
# 4  0.235586  0.234031    0.001753  0.055135          0.081998        0.332071
#
#    car_plate_ratio  plate_proportions  car_proportions  car_to_bottom  \
# 0         0.031827           0.296296         1.031083       0.330585
# 1         0.027619           0.247191         1.048718       0.401631
# 2         0.034596           0.323471         1.168759       0.429774
# 3         0.030968           0.275229         1.157380       0.380994
# 4         0.031794           0.281346         0.993399       0.397181
#
#    distance
# 0      2.20
# 1      3.72
# 2      4.98
# 3      4.30
# 4      2.66

# %% [markdown]
# # Подготовка Test и предсказания алгоритма

# %% [markdown]
# ## 1. Подготовка test

# %% [markdown]
# Несмотря на то, что на большинстве фото распознаны ровно один автомобиль и один номер, на нескольких фото алгоритм детектирования не отработал как предполагалось. Функция analyze_detections ниже решают данную проблему добавлением или удалением детекций.

# %%
def analyze_detections(detections):
    '''
    Функция убирает лишние детекции и заполняет пропуски, 
    в случае если распознан только номер/автомобиль или вообще ничего не распознано.
    
    Добавление детекций происходит за счет похожих детекций на других фото
    
    На выходе только две детекции: автомобиль и номер
    '''
    if len(detections)==0:
        # если ничего не распознано берем усредненные детекции по train
        x_car, y_car, w_car, h_car = np.mean(train['x_car']), np.mean(train['y_car']), np.mean(train['w_car']), np.mean(train['h_car'])
        x_plate, y_plate, w_plate, h_plate = np.mean(train['x_plate']), np.mean(train['y_plate']), np.mean(train['w_plate']), np.mean(train['h_plate'])
    elif len(detections)==1:
        label, x, y, w, h, conf = list(map(float,detections[0].split()))
        if int(label)==0:
            x_car, y_car, w_car, h_car = x, y, w, h
            similar_cars = train[abs(train.car_area-w_car*h_car)<0.05]
            Y_OFFSET = np.mean(similar_cars['y_car']-similar_cars['y_plate'])
            WIDTH_RATIO = np.mean(similar_cars['w_car']/similar_cars['w_plate'])
            HEIGHT_RATIO = np.mean(similar_cars['h_car']/similar_cars['h_plate'])
            
            x_plate, y_plate, w_plate, h_plate = x_car, y_car-Y_OFFSET, w_car/WIDTH_RATIO, h_car/HEIGHT_RATIO
        else:
            x_plate, y_plate, w_plate, h_plate = x, y, w, h
            x_car, y_car, w_car, h_car = x_plate+X_OFFSET, y_car+Y_OFFSET, w_plate*WIDTH_RATIO, h_plate*HEIGHT_RATIO
    elif len(detections)>2:
        car_detections = []
        plate_detections = []
        
        for i, line in enumerate(detections):
            label, x, y, w, h, conf = list(map(float,line.split()))
            if int(label)==0:
                car_detections.append([x, y, w, h, conf])
            else:
                plate_detections.append([x, y, w, h, conf])
        
        car_detections, plate_detections = np.array(car_detections), np.array(plate_detections)
        x_car, y_car, w_car, h_car, conf = car_detections[np.argmax(car_detections[:, 4])]
        x_plate, y_plate, w_plate, h_plate, conf = plate_detections[np.argmax(plate_detections[:, 4])]
    
    return x_car, y_car, w_car, h_car, x_plate, y_plate, w_plate, h_plate

def test_detections_to_features_df(path_to_images):
    '''
    Функция принимает на вход путь к папке с детекциями и возвращает датафрейм с фичами по каждой фото
    '''
    records = []
    for img_name in glob.glob(path_to_images+'*.jpg'):
        img_name = img_name.split('/')[-1]
        label_name = img_name.split('.')[0]+'.txt'
        
        if label_name not in os.listdir(path_to_images+'labels/'):
            with open(path_to_images+'labels/'+label_name, 'w') as f:
                f.write('')
        
        with open(path_to_images+'labels/'+label_name, 'r') as f:
            lines = f.read().splitlines()
            if len(lines)!=2:
                x_car, y_car, w_car, h_car, x_plate, y_plate, w_plate, h_plate = analyze_detections(lines)
                records.append([img_name, x_plate, y_plate, w_plate, h_plate, x_car, y_car, w_car, h_car])
            else:
                for i, line in enumerate(lines):
                    label, x, y, w, h, conf = list(map(float,line.split()))
                    if int(label)==0:
                        x_car, y_car, w_car, h_car = x, y, w, h
                    else:
                        x_plate, y_plate, w_plate, h_plate = x, y, w, h

                
                records.append([img_name, x_plate, y_plate, w_plate, h_plate, x_car, y_car, w_car, h_car])
        
    
    df = pd.DataFrame(records, columns=['image_name', 'x_plate', 'y_plate', 'w_plate',
                                          'h_plate', 'x_car', 'y_car', 'w_car', 'h_car'])
    
    df['plate_area'] = df['w_plate']*df['h_plate']
    df['car_area'] = df['w_car']*df['h_car']
    df['plate_hypotenuse'] = (df['w_plate']**2 + df['h_plate']**2).apply(sqrt)
    df['car_hypotenuse'] = (df['w_car']**2 + df['h_car']**2).apply(sqrt)
    df['car_plate_ratio'] = df['plate_area'] / df['car_area']
    df['plate_proportions'] = df['h_plate']/df['w_plate']
    df['car_proportions'] = df['h_car']/df['w_car']
    df['car_to_bottom'] = 1 - (df['y_car']+df['h_car']/2)
    
    return df

# %%
test = test_detections_to_features_df('models/yolov5/runs/detect/test_dets_4_conf_65_img_1200/')
test.shape
# Out:
# (521, 17)

# %%
test.head()
# Out:
#        image_name   x_plate   y_plate   w_plate   h_plate     x_car     y_car  \
# 0    img_2603.jpg  0.462813  0.507083  0.040625  0.010833  0.461563  0.505417
# 1    img_2617.jpg  0.488125  0.518333  0.032500  0.008333  0.487812  0.513750
# 2    img_1875.jpg  0.476250  0.520833  0.032500  0.008333  0.475937  0.505417
# 3    img_1849.jpg  0.473750  0.497083  0.042500  0.012500  0.468750  0.492083
# 4  img_2697_1.jpg  0.487500  0.498750  0.028750  0.009167  0.487188  0.472500
#
#       w_car     h_car  plate_area  car_area  plate_hypotenuse  car_hypotenuse  \
# 0  0.124375  0.139167    0.000440  0.017309          0.042045        0.186646
# 1  0.099375  0.117500    0.000271  0.011677          0.033551        0.153888
# 2  0.096875  0.110833    0.000271  0.010737          0.033551        0.147203
# 3  0.128750  0.139167    0.000531  0.017918          0.044300        0.189589
# 4  0.088125  0.098333    0.000264  0.008666          0.030176        0.132043
#
#    car_plate_ratio  plate_proportions  car_proportions  car_to_bottom
# 0         0.025426           0.266666         1.118931       0.424999
# 1         0.023195           0.256410         1.182390       0.427500
# 2         0.025224           0.256410         1.144083       0.439167
# 3         0.029649           0.294118         1.080909       0.438334
# 4         0.030412           0.318841         1.115839       0.478333

# %% [markdown]
# ## 2. Предсказание дистанции

# %%
# Tensorflow sequential model
import tensorflow as tf

model = tf.keras.models.load_model('models/main_model')

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 1024)              17408
#
#  dropout_6 (Dropout)         (None, 1024)              0
#
#  dense_10 (Dense)            (None, 512)               524800
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_11 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 542,721
# Trainable params: 542,721
# Non-trainable params: 0
# _________________________________________________________________

# %%
test['distance'] = np.squeeze(model.predict(test.loc[:, 'x_plate':'car_to_bottom'].values), axis=1)
test.head()
# Out:
#        image_name   x_plate   y_plate   w_plate   h_plate     x_car     y_car  \
# 0    img_2603.jpg  0.462813  0.507083  0.040625  0.010833  0.461563  0.505417
# 1    img_2617.jpg  0.488125  0.518333  0.032500  0.008333  0.487812  0.513750
# 2    img_1875.jpg  0.476250  0.520833  0.032500  0.008333  0.475937  0.505417
# 3    img_1849.jpg  0.473750  0.497083  0.042500  0.012500  0.468750  0.492083
# 4  img_2697_1.jpg  0.487500  0.498750  0.028750  0.009167  0.487188  0.472500
#
#       w_car     h_car  plate_area  car_area  plate_hypotenuse  car_hypotenuse  \
# 0  0.124375  0.139167    0.000440  0.017309          0.042045        0.186646
# 1  0.099375  0.117500    0.000271  0.011677          0.033551        0.153888
# 2  0.096875  0.110833    0.000271  0.010737          0.033551        0.147203
# 3  0.128750  0.139167    0.000531  0.017918          0.044300        0.189589
# 4  0.088125  0.098333    0.000264  0.008666          0.030176        0.132043
#
#    car_plate_ratio  plate_proportions  car_proportions  car_to_bottom  \
# 0         0.025426           0.266666         1.118931       0.424999
# 1         0.023195           0.256410         1.182390       0.427500
# 2         0.025224           0.256410         1.144083       0.439167
# 3         0.029649           0.294118         1.080909       0.438334
# 4         0.030412           0.318841         1.115839       0.478333
#
#    distance
# 0  5.144441
# 1  6.578923
# 2  6.518903
# 3  4.846159
# 4  7.203343

# %%
test.shape
# Out:
# (521, 18)

# %%
test = test[['image_name', 'distance']]

# %% [markdown]
# ## 3. Файл submission.csv

# %% [markdown]
# Переходим к оригинальным названиям файлов и расширениям

# %%
def back_to_heic(img_name):
    '''
    if '_1.jpg' in img_name:
        heic_images.remove(img_name.split('_1.jpg')[0])
        return img_name.split('_1.jpg')[0]+'.heic'
    elif img_name.split('.')[0] in heic_images:
        heic_images.remove(img_name.split('.')[0])
        return img_name.split('.')[0]+'.heic'
    '''
    if '_1.jpg' in img_name:
        result = img_name.split('_1.jpg')[0]+'.heic'
        print(img_name+' converted to ', result)
        return result
    
    if (img_name.split('.')[0] in heic_images) and (img_name.split('.')[0] not in jpg_images):
        result = img_name.split('.')[0]+'.heic'
        print(img_name+' converted to ', result)
        return result

    print(img_name+' - no conversion')
    return img_name


test_annot = pd.read_csv('test.csv', sep=';')
heic_images = []
jpg_images = []
for img_name in test_annot['image_name']:
    if img_name.split('.')[1]=='heic':
        heic_images.append(img_name.split('.')[0])
    else:
        jpg_images.append(img_name.split('.')[0])
        
test['image_name'] = test['image_name'].apply(back_to_heic)
# Out:
# img_2603.jpg - no conversion
# img_2617.jpg - no conversion
# img_1875.jpg - no conversion
# img_1849.jpg - no conversion
# img_2697_1.jpg converted to  img_2697.heic
# img_2401.jpg - no conversion
# img_2367.jpg - no conversion
# img_2415.jpg - no conversion
# img_1652.jpg - no conversion
# img_1646.jpg - no conversion
# img_1915.jpg - no conversion
# img_2011.jpg - no conversion
# img_2777.jpg - no conversion
# img_2762.jpg - no conversion
# img_2004.jpg - no conversion
# img_2776.jpg - no conversion
# img_2560.jpg - no conversion
# img_1928.jpg - no conversion
# img_1914.jpg - no conversion
# img_1900.jpg - no conversion
# img_2428.jpg - no conversion
# img_2414.jpg - no conversion
# img_2400.jpg - no conversion
# img_2366.jpg - no conversion
# img_2399.jpg - no conversion
# img_2753_1.jpg converted to  img_2753.heic
# img_2616.jpg - no conversion
# img_2602.jpg - no conversion
# img_2628.jpg - no conversion
# img_1876.jpg - no conversion
# img_2416.jpg - no conversion
# img_2370.jpg - no conversion
# img_1679.jpg - no conversion
# img_2364.jpg - no conversion
# img_2402.jpg - no conversion
# img_2358.jpg - no conversion
# img_1889.jpg - no conversion
# img_1651.jpg - no conversion
# img_2589.jpg - no conversion
# img_1719.jpg - no conversion
# img_2576.jpg - no conversion
# img_2006.jpg - no conversion
# img_2749.jpg - no conversion
# img_2013.jpg - no conversion
# img_2761.jpg - no conversion
# img_2946.jpg - no conversion
# img_1718.jpg - no conversion
# img_1917.jpg - no conversion
# img_1888.jpg - no conversion
# img_1644.jpg - no conversion
# img_2365.jpg - no conversion
# img_2403.jpg - no conversion
# img_2417.jpg - no conversion
# img_1678.jpg - no conversion
# img_2371.jpg - no conversion
# img_1693.jpg - no conversion
# img_1877.jpg - no conversion
# img_2826.jpg - no conversion
# img_2611.jpg - no conversion
# img_2605.jpg - no conversion
# img_1683.jpg - no conversion
# img_1697.jpg - no conversion
# img_1867.jpg - no conversion
# img_1873.jpg - no conversion
# img_1898.jpg - no conversion
# img_2349.jpg - no conversion
# img_1654.jpg - no conversion
# img_2375.jpg - no conversion
# img_2413.jpg - no conversion
# img_2407.jpg - no conversion
# img_2598.jpg - no conversion
# img_1913.jpg - no conversion
# img_1720.jpg - no conversion
# img_2567.jpg - no conversion
# img_2573.jpg - no conversion
# img_2942.jpg - no conversion
# img_2759.jpg - no conversion
# img_2017.jpg - no conversion
# img_2771.jpg - no conversion
# img_2758.jpg - no conversion
# img_2943.jpg - no conversion
# img_2572.jpg - no conversion
# img_2566.jpg - no conversion
# img_1906.jpg - no conversion
# img_2599.jpg - no conversion
# img_2360.jpg - no conversion
# img_2412.jpg - no conversion
# img_1655.jpg - no conversion
# img_1872.jpg - no conversion
# img_1866.jpg - no conversion
# img_1682.jpg - no conversion
# img_2610.jpg - no conversion
# img_2606.jpg - no conversion
# img_2612.jpg - no conversion
# img_1694.jpg - no conversion
# img_2389.jpg - no conversion
# img_1858.jpg - no conversion
# img_1870.jpg - no conversion
# img_2677_1.jpg converted to  img_2677.heic
# img_1657.jpg - no conversion
# img_2438.jpg - no conversion
# img_2362.jpg - no conversion
# img_1904.jpg - no conversion
# img_2558.jpg - no conversion
# img_2564.jpg - no conversion
# img_2028.jpg - no conversion
# img_2772.jpg - no conversion
# img_2773.jpg - no conversion
# img_2015.jpg - no conversion
# img_2029.jpg - no conversion
# img_2693_1.jpg converted to  img_2693.heic
# img_2798.jpg - no conversion
# img_2565.jpg - no conversion
# img_2571.jpg - no conversion
# img_2559.jpg - no conversion
# img_2736_1.jpg converted to  img_2736.heic
# img_1911.jpg - no conversion
# img_1905.jpg - no conversion
# img_2377.jpg - no conversion
# img_2363.jpg - no conversion
# img_1642.jpg - no conversion
# img_2439.jpg - no conversion
# img_1871.jpg - no conversion
# img_1859.jpg - no conversion
# img_2388.jpg - no conversion
# img_1695.jpg - no conversion
# img_2607.jpg - no conversion
# img_2674.jpg converted to  img_2674.heic
# img_2884.jpg - no conversion
# img_2489.jpg - no conversion
# img_2338.jpg - no conversion
# img_1625.jpg - no conversion
# img_1962.jpg - no conversion
# img_2258.jpg - no conversion
# img_1989.jpg - no conversion
# img_2715_1.jpg converted to  img_2715.heic
# img_2933.jpg - no conversion
# img_2714.jpg - no conversion
# img_2700.jpg - no conversion
# img_2728.jpg converted to  img_2728.heic
# img_2729.jpg - no conversion
# img_2701.jpg - no conversion
# img_2715.jpg - no conversion
# img_2926.jpg - no conversion
# img_1988.jpg - no conversion
# img_2259.jpg - no conversion
# img_2265.jpg - no conversion
# img_2517.jpg - no conversion
# img_2731_1.jpg converted to  img_2731.heic
# img_2339.jpg - no conversion
# img_1630.jpg - no conversion
# img_2311.jpg - no conversion
# img_2488.jpg - no conversion
# img_2649.jpg - no conversion
# img_2675.jpg - no conversion
# img_2661.jpg - no conversion
# img_2878.jpg - no conversion
# img_2677.jpg - no conversion
# img_2663.jpg - no conversion
# img_2893.jpg - no conversion
# img_2887.jpg - no conversion
# img_2475.jpg - no conversion
# img_2461.jpg - no conversion
# img_2307.jpg - no conversion
# img_1632.jpg - no conversion
# img_1975.jpg - no conversion
# img_1961.jpg - no conversion
# img_1949.jpg - no conversion
# img_2298.jpg - no conversion
# img_2267.jpg - no conversion
# img_2501.jpg - no conversion
# img_2515.jpg - no conversion
# img_2273.jpg - no conversion
# img_2529.jpg - no conversion
# img_2924.jpg - no conversion
# img_2703.jpg - no conversion
# img_2717.jpg - no conversion
# img_2716.jpg converted to  img_2716.heic
# img_2702.jpg - no conversion
# img_2919.jpg - no conversion
# img_2500.jpg - no conversion
# img_2299.jpg - no conversion
# img_2717_1.jpg converted to  img_2717.heic
# img_2752_1.jpg converted to  img_2752.heic
# img_1960.jpg - no conversion
# img_1974.jpg - no conversion
# img_1633.jpg - no conversion
# img_2448.jpg - no conversion
# img_2312.jpg - no conversion
# img_1828.jpg - no conversion
# img_2886.jpg - no conversion
# img_2662.jpg - no conversion
# img_2676.jpg - no conversion
# img_2689.jpg - no conversion
# img_2699.jpg - no conversion
# img_2464.jpg - no conversion
# img_2262.jpg - no conversion
# img_2276.jpg - no conversion
# img_2921.jpg - no conversion
# img_2935.jpg - no conversion
# img_2909.jpg - no conversion
# img_2706.jpg converted to  img_2706.heic
# img_2712.jpg converted to  img_2712.heic
# img_2713.jpg converted to  img_2713.heic
# img_2707.jpg converted to  img_2707.heic
# img_1597.jpg - no conversion
# img_2263.jpg - no conversion
# img_2288.jpg - no conversion
# img_2303.jpg - no conversion
# img_2465.jpg - no conversion
# img_2471.jpg - no conversion
# img_2317.jpg - no conversion
# img_1636.jpg - no conversion
# img_1622.jpg - no conversion
# img_1839.jpg - no conversion
# img_2868.jpg - no conversion
# img_2692_1.jpg converted to  img_2692.heic
# img_2698.jpg - no conversion
# img_2498.jpg - no conversion
# img_2329.jpg - no conversion
# img_2467.jpg - no conversion
# img_2315.jpg - no conversion
# img_2473.jpg - no conversion
# img_1998.jpg - no conversion
# img_2513.jpg - no conversion
# img_2936.jpg - no conversion
# img_2922.jpg - no conversion
# img_2739.jpg converted to  img_2739.heic
# img_2711.jpg - no conversion
# img_2704.jpg converted to  img_2704.heic
# img_2710.jpg - no conversion
# img_2738.jpg - no conversion
# img_2689_1.jpg converted to  img_2689.heic
# img_2923.jpg - no conversion
# img_2506.jpg - no conversion
# img_2274.jpg - no conversion
# img_1999.jpg - no conversion
# img_1972.jpg - no conversion
# img_2314.jpg - no conversion
# img_2472.jpg - no conversion
# img_2466.jpg - no conversion
# img_1609.jpg - no conversion
# img_2328.jpg - no conversion
# img_2711_1.jpg converted to  img_2711.heic
# img_2499.jpg - no conversion
# img_2670.jpg - no conversion
# img_2880.jpg - no conversion
# img_2696.jpg - no conversion
# img_2641.jpg - no conversion
# img_2655.jpg - no conversion
# img_1823.jpg - no conversion
# img_2325.jpg - no conversion
# img_2457.jpg - no conversion
# img_1638.jpg - no conversion
# img_1610.jpg - no conversion
# img_1604.jpg - no conversion
# img_2292.jpg - no conversion
# img_1943.jpg - no conversion
# img_1957.jpg - no conversion
# img_2286.jpg - no conversion
# img_2537.jpg - no conversion
# img_2523.jpg - no conversion
# img_2279.jpg - no conversion
# img_1599.jpg - no conversion
# img_2906.jpg - no conversion
# img_2720_1.jpg converted to  img_2720.heic
# img_2708.jpg converted to  img_2708.heic
# img_2720.jpg - no conversion
# img_2734.jpg - no conversion
# img_2907.jpg - no conversion
# img_1598.jpg - no conversion
# img_2522.jpg - no conversion
# img_1995.jpg - no conversion
# img_1981.jpg - no conversion
# img_1956.jpg - no conversion
# img_1942.jpg - no conversion
# img_2293.jpg - no conversion
# img_1611.jpg - no conversion
# img_2318.jpg - no conversion
# img_2456.jpg - no conversion
# img_1639.jpg - no conversion
# img_2324.jpg - no conversion
# img_1836.jpg - no conversion
# img_2481.jpg - no conversion
# img_2668.jpg - no conversion
# img_2898.jpg - no conversion
# img_2640.jpg - no conversion
# img_2873.jpg - no conversion
# img_2697.jpg - no conversion
# img_2695.jpg - no conversion
# img_2859.jpg - no conversion
# img_2871.jpg - no conversion
# img_2865.jpg - no conversion
# img_2497.jpg - no conversion
# img_2483.jpg - no conversion
# img_2326.jpg - no conversion
# img_1954.jpg - no conversion
# img_1940.jpg - no conversion
# img_1997.jpg - no conversion
# img_2534.jpg - no conversion
# img_2508.jpg - no conversion
# img_2722.jpg - no conversion
# img_2736.jpg - no conversion
# img_2910.jpg - no conversion
# img_2938.jpg - no conversion
# img_2509.jpg - no conversion
# img_1982.jpg - no conversion
# img_2521.jpg - no conversion
# img_1969.jpg - no conversion
# img_1941.jpg - no conversion
# img_2284.jpg - no conversion
# img_1955.jpg - no conversion
# img_2441.jpg - no conversion
# img_2482.jpg - no conversion
# img_1821.jpg - no conversion
# img_2496.jpg - no conversion
# img_2864.jpg - no conversion
# img_2680.jpg - no conversion
# img_2684.jpg converted to  img_2684.heic
# img_2653.jpg - no conversion
# img_2647.jpg - no conversion
# img_1819.jpg - no conversion
# img_1825.jpg - no conversion
# img_2486.jpg - no conversion
# img_1602.jpg - no conversion
# img_2479.jpg - no conversion
# img_2337.jpg - no conversion
# img_2323.jpg - no conversion
# img_2525.jpg - no conversion
# img_1986.jpg - no conversion
# img_2257.jpg - no conversion
# img_2531.jpg - no conversion
# img_2900.jpg - no conversion
# img_2914.jpg - no conversion
# img_2727.jpg - no conversion
# img_2733.jpg - no conversion
# img_2732.jpg converted to  img_2732.heic
# img_2726.jpg - no conversion
# img_2929.jpg - no conversion
# img_1987.jpg - no conversion
# img_2530.jpg - no conversion
# img_2524.jpg - no conversion
# img_1993.jpg - no conversion
# img_2518.jpg - no conversion
# img_1944.jpg - no conversion
# img_2281.jpg - no conversion
# img_1978.jpg - no conversion
# img_2444.jpg - no conversion
# img_1617.jpg - no conversion
# img_2478.jpg - no conversion
# img_1830.jpg - no conversion
# img_2493.jpg - no conversion
# img_2702_1.jpg converted to  img_2702.heic
# img_2652.jpg - no conversion
# img_2685.jpg - no conversion
# img_2875.jpg - no conversion
# img_2877.jpg - no conversion
# img_2687.jpg - no conversion
# img_2693.jpg - no conversion
# img_2678.jpg - no conversion
# img_2644.jpg - no conversion
# img_2888.jpg - no conversion
# img_1826.jpg - no conversion
# img_2491.jpg - no conversion
# img_2446.jpg - no conversion
# img_1629.jpg - no conversion
# img_2334.jpg - no conversion
# img_1946.jpg - no conversion
# img_1952.jpg - no conversion
# img_2283.jpg - no conversion
# img_2532.jpg - no conversion
# img_2698_1.jpg converted to  img_2698.heic
# img_2526.jpg - no conversion
# img_2917.jpg - no conversion
# img_2718.jpg - no conversion
# img_2724.jpg - no conversion
# img_2725.jpg converted to  img_2725.heic
# img_2731.jpg - no conversion
# img_2719.jpg - no conversion
# img_1990.jpg - no conversion
# img_2719_1.jpg converted to  img_2719.heic
# img_1953.jpg - no conversion
# img_1947.jpg - no conversion
# img_2335.jpg - no conversion
# img_2447.jpg - no conversion
# img_1833.jpg - no conversion
# img_2889.jpg - no conversion
# img_2679.jpg - no conversion
# img_2692.jpg - no conversion
# img_2686.jpg converted to  img_2686.heic
# img_2622.jpg - no conversion
# img_2391.jpg - no conversion
# img_1698.jpg - no conversion
# img_1840.jpg - no conversion
# img_1868.jpg - no conversion
# img_2346.jpg - no conversion
# img_1897.jpg - no conversion
# img_1920.jpg - no conversion
# img_1934.jpg - no conversion
# img_1908.jpg - no conversion
# img_2540.jpg - no conversion
# img_2781.jpg - no conversion
# img_2756.jpg - no conversion
# img_2742.jpg converted to  img_2742.heic
# img_2024.jpg - no conversion
# img_2019.jpg - no conversion
# img_2757.jpg - no conversion
# img_2569.jpg - no conversion
# img_1706.jpg - no conversion
# img_2541.jpg - no conversion
# img_2555.jpg - no conversion
# img_1935.jpg - no conversion
# img_2582.jpg - no conversion
# img_2596.jpg - no conversion
# img_2353.jpg - no conversion
# img_2435.jpg - no conversion
# img_2421.jpg - no conversion
# img_1869.jpg - no conversion
# img_1699.jpg - no conversion
# img_1855.jpg - no conversion
# img_2637.jpg - no conversion
# img_2609.jpg - no conversion
# img_2392.jpg - no conversion
# img_1843.jpg - no conversion
# img_2386.jpg - no conversion
# img_1880.jpg - no conversion
# img_2351.jpg - no conversion
# img_1894.jpg - no conversion
# img_2679_1.jpg converted to  img_2679.heic
# img_1664.jpg - no conversion
# img_2379.jpg - no conversion
# img_2580.jpg - no conversion
# img_1923.jpg - no conversion
# img_2594.jpg - no conversion
# img_2543.jpg - no conversion
# img_2557.jpg - no conversion
# img_1710.jpg - no conversion
# img_1704.jpg - no conversion
# img_2782.jpg - no conversion
# img_2755.jpg converted to  img_2755.heic
# img_2769.jpg - no conversion
# img_2768.jpg - no conversion
# img_2754.jpg - no conversion
# img_2740.jpg - no conversion
# img_1705.jpg - no conversion
# img_2556.jpg - no conversion
# img_2542.jpg - no conversion
# img_2595.jpg - no conversion
# img_1936.jpg - no conversion
# img_1895.jpg - no conversion
# img_1659.jpg - no conversion
# img_2387.jpg - no conversion
# img_1842.jpg - no conversion
# img_2393.jpg - no conversion
# img_2618.jpg - no conversion
# img_1846.jpg - no conversion
# img_1852.jpg - no conversion
# img_2368.jpg - no conversion
# img_1661.jpg - no conversion
# img_2354.jpg - no conversion
# img_2340.jpg - no conversion
# img_1891.jpg - no conversion
# img_2585.jpg - no conversion
# img_2591.jpg - no conversion
# img_1701.jpg - no conversion
# img_2546.jpg - no conversion
# img_2552.jpg - no conversion
# img_2778.jpg - no conversion
# img_2744.jpg - no conversion
# img_2022.jpg - no conversion
# img_2750.jpg converted to  img_2750.heic
# img_2023.jpg - no conversion
# img_1648.jpg - no conversion
# img_2355.jpg - no conversion
# img_1884.jpg - no conversion
# img_2433.jpg - no conversion
# img_1660.jpg - no conversion
# img_2718_1.jpg converted to  img_2718.heic
# img_2382.jpg - no conversion
# img_2396.jpg - no conversion
# img_2619.jpg - no conversion
# img_2800.jpg - no conversion
# img_2633.jpg - no conversion
# img_1879.jpg - no conversion
# img_1689.jpg - no conversion
# img_1851.jpg - no conversion
# img_2380.jpg - no conversion
# img_2394.jpg - no conversion
# img_2419.jpg - no conversion
# img_2343.jpg - no conversion
# img_1892.jpg - no conversion
# img_2425.jpg - no conversion
# img_2431.jpg - no conversion
# img_2357.jpg - no conversion
# img_1919.jpg - no conversion
# img_2592.jpg - no conversion
# img_1931.jpg - no conversion
# img_1702.jpg - no conversion
# img_1716.jpg - no conversion
# img_2551.jpg - no conversion
# img_2545.jpg - no conversion
# img_2790.jpg - no conversion
# img_2784.jpg - no conversion
# img_2009.jpg - no conversion
# img_2753.jpg - no conversion
# img_2020.jpg - no conversion
# img_2746.jpg - no conversion
# img_2752.jpg - no conversion
# img_2785.jpg - no conversion
# img_1717.jpg - no conversion
# img_1703.jpg - no conversion
# img_2587.jpg - no conversion
# img_2703_1.jpg converted to  img_2703.heic
# img_2356.jpg - no conversion
# img_2424.jpg - no conversion
# img_1663.jpg - no conversion
# img_1844.jpg - no conversion
# img_2395.jpg - no conversion
# img_2381.jpg - no conversion
# img_2632.jpg - no conversion
# img_2626.jpg - no conversion

# %%
test.head()
# Out:
#       image_name  distance
# 0   img_2603.jpg  5.144441
# 1   img_2617.jpg  6.578923
# 2   img_1875.jpg  6.518903
# 3   img_1849.jpg  4.846159
# 4  img_2697.heic  7.203343

# %%
test.to_csv('submission_final.csv',index=False, sep=';')
